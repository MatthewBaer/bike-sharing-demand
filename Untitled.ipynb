# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.cross_validation import train_test_split

# %%
training_data = pd.read_csv('/scratch/mparker3/train.csv')
test_data = pd.read_csv('/scratch/mparker3/test.csv')

# %%
x_data = []
y_data = []
for i in training_data["count"]:
    y_data.append(i)
y_train = np.array(y_data)
for i in range(len(training_data["count"])):
    data = []
    for j in training_data:
        if j != "datetime" and j != "count":
            data.append(int(training_data[j][i]))
    npdata = np.array(data)
    x_data.append(npdata)

x_train = np.array(x_data)
x_max = x_train.max()
x_min = x_train.min()
x_train_vectors = (x_train.reshape(10886, 10) - x_min) / float(x_max - x_min)
print x_train.shape
print y_train.shape

X_train, X_test, y_train, y_test = train_test_split(x_train_vectors, y_train, test_size=0.2, random_state=0)
# Out:
# (10886, 10)
# (10886,)

# %%
regressor = DecisionTreeRegressor(max_depth=8)
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=8, max_features=None,
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
y_test_results = regressor.predict(X_test)

for i in range(len(y_test)):
    print("predicted: " + str(y_test_results[i]) + " actual: " + str(y_test[i]))
# Out:
# predicted: 246.796610169 actual: 244
# predicted: 243.879518072 actual: 239
# predicted: 223.826530612 actual: 229
# predicted: 483.068965517 actual: 467
# predicted: 346.380952381 actual: 335
# predicted: 35.0 actual: 40
# predicted: 346.380952381 actual: 329
# predicted: 1.85650224215 actual: 2
# predicted: 133.448275862 actual: 141
# predicted: 390.7125 actual: 391
# predicted: 101.017241379 actual: 104
# predicted: 131.12244898 actual: 126
# predicted: 214.333333333 actual: 202
# predicted: 144.098360656 actual: 149
# predicted: 182.693877551 actual: 187
# predicted: 306.246153846 actual: 283
# predicted: 409.461538462 actual: 413
# predicted: 144.098360656 actual: 133
# predicted: 69.75 actual: 68
# predicted: 3.59259259259 actual: 4
# predicted: 20.9042553191 actual: 20
# predicted: 452.666666667 actual: 450
# predicted: 128.878787879 actual: 136
# predicted: 21.6304347826 actual: 20
# predicted: 30.3965517241 actual: 31
# predicted: 101.017241379 actual: 106
# ...
